# %%
import numpy as np

# Generate random scores
scores = np.random.randint(0, 100, size=50)

print("Scores:")
print(scores)

# Statistics
print("\nMean:", np.mean(scores))
print("Median:", np.median(scores))
print("Highest:", np.max(scores))
print("Lowest:", np.min(scores))
print("Standard Deviation:", np.std(scores))

# Percentiles
print("25th Percentile:", np.percentile(scores, 25))
print("75th Percentile:", np.percentile(scores, 75))

# Failed and distinction students
print("\nFailed Students (<40):")
print(scores[scores < 40])

print("\nDistinction Students (>85):")
print(scores[scores > 85])

# Normalize scores
normalized_scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

print("\nNormalized Scores:")
print(normalized_scores)

# Reshape array
reshaped_scores = scores.reshape(5, 10)

print("\n5x10 Score Matrix:")
print(reshaped_scores)

# Row-wise averages
subject_avg = np.mean(reshaped_scores, axis=1)

print("\nSubject-wise Average Scores:")
print(subject_avg)

# Bonus challenge
theory = np.random.randint(0, 100, size=50)
practical = np.random.randint(0, 100, size=50)

final_scores = (0.4 * theory) + (0.6 * practical)

print("\nWeighted Final Scores:")
print(final_scores)
# Out:
# Scores:
# [18 71 12 32 65 12 18 66 86 13 63 12 81 90 35 32  1 83 13 49 48 18 42 62
#  18  8 88 26 92 59 69  6 50 18 18 34 79 53  7 63  4 45 67 26 96  6 10 50
#   7  3]
#
# Mean: 40.48
# Median: 34.5
# Highest: 96
# Lowest: 1
# Standard Deviation: 28.973256634351614
# 25th Percentile: 13.0
# 75th Percentile: 64.5
#
# Failed Students (<40):
# [18 12 32 12 18 13 12 35 32  1 13 18 18  8 26  6 18 18 34  7  4 26  6 10
#   7  3]
#
# Distinction Students (>85):
# [86 90 88 92 96]
#
# Normalized Scores:
# [0.17894737 0.73684211 0.11578947 0.32631579 0.67368421 0.11578947
#  0.17894737 0.68421053 0.89473684 0.12631579 0.65263158 0.11578947
#  0.84210526 0.93684211 0.35789474 0.32631579 0.         0.86315789
#  0.12631579 0.50526316 0.49473684 0.17894737 0.43157895 0.64210526
#  0.17894737 0.07368421 0.91578947 0.26315789 0.95789474 0.61052632
#  0.71578947 0.05263158 0.51578947 0.17894737 0.17894737 0.34736842
#  0.82105263 0.54736842 0.06315789 0.65263158 0.03157895 0.46315789
#  0.69473684 0.26315789 1.         0.05263158 0.09473684 0.51578947
#  0.06315789 0.02105263]
#
# 5x10 Score Matrix:
# [[18 71 12 32 65 12 18 66 86 13]
#  [63 12 81 90 35 32  1 83 13 49]
#  [48 18 42 62 18  8 88 26 92 59]
#  [69  6 50 18 18 34 79 53  7 63]
#  [ 4 45 67 26 96  6 10 50  7  3]]
#
# Subject-wise Average Scores:
# [39.3 45.9 46.1 39.7 31.4]
#
# Weighted Final Scores:
# [62.8 52.8 35.2 24.4 51.2 71.2 64.6 39.8 50.6 29.6 51.8 33.6 38.  30.2
#  67.2 14.2 67.  56.  77.4 53.6 81.  67.2 46.4 42.6 25.4 80.  56.  31.6
#  55.8 31.4 19.2 37.4 37.8 40.8 14.8 17.  13.4 57.6 26.2 39.  62.6 68.
#  45.8 62.  63.8 76.8 25.6 61.4 70.8 54.2]
